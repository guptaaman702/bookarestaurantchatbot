# %%
import sqlite3

conn = sqlite3.connect('restuarantbooking.db')
print("Opened database successfully");
# Out:
# Opened database successfully

# %%
'''Create the table'''
conn.execute('''CREATE TABLE RESTAURANTRESERVATION
         (ID               INTEGER PRIMARY KEY AUTOINCREMENT,
         RESERVEDONTHENAME TEXT    NOT NULL,
         RESTAURANTNAME    TEXT    NOT NULL,
         CUISINETYPE       TEXT    NOT NULL,
         COSTTYPE          TEXT    NOT NULL,
         LOCATION          TEXT    NOT NULL,
         NOOFPEOPLE        TEXT    NOT NULL);''');
print("Restaurant Table created successfully");
conn.close()
# Out:
# Restaurant Table created successfully

# %%
conn = sqlite3.connect('restuarantbooking.db')

conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('AMAN','SWAGATH','CHINESE','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('AMAN','SWAD','CHINESE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAGHAVA','SHAH GOUSE','NORTH INDIAN','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAGHAVA','PARADISE','NORTH INDIAN','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAGHAVA','PARADISE','NORTH INDIAN','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAGHAVA','PARADISE','SOUTH INDIAN','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAGHAVA','PARADISE','SOUTH INDIAN','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAGHAVA','SWAD','SOUTH INDIAN','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('SRINIVAS','SHAH GOUSE','ITALIAN','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('SRINIVAS','SHAH GOUSE','ITALIAN','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('SRINIVAS','PARADISE','ITALIAN','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('MURALI','PARADISE','SPANISH','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('MURALI','PARADISE','SPANISH','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('MURALI','PARADISE','SPANISH','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('SRINIVAS','PARADISE','CONTINENTAL','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('SRINIVAS','SWAD','CONTINENTAL','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('SRINIVAS','PARADISE','CONTINENTAL','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('AMAN','SWAD','MULTI CUISINE','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('AMAN','PARADISE','MULTI CUISINE','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('AMAN','PARADISE','MULTI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('AMAN','OHRIS','MEXICAN','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('AMAN','PARADISE','MEXICAN','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('AMAN','PARADISE','MEXICAN','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('SUDANSHU','SWAD','MEDITERRANEAN','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('SUDANSHU','SWAD','MEDITERRANEAN','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('SUDANSHU','SWAD','MEDITERRANEAN','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE1','PUNJABI','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','PUNJABI','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SWAD','PUNJABI','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','HYDERABADI','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','HYDERABADI','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SWAD','HYDERABADI','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','RAJASTHANI','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','RAJASTHANI','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SWAD','RAJASTHANI','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','INDIAN FAST FOODS','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','INDIAN FAST FOODS','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','INDIAN FAST FOODS','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SIMPYSOUTH','CUISINE OF KARNATAKA','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SIMPYSOUTH','TELANGANA CUISINE','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SIMPYSOUTH','HYDERABADI CUISINE','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SIMPYSOUTH','EAST INDIAN CUISINES','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SUBWAY','AWADHI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','PUNJABI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','CUISINE OF UTTAR PRADESH','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SUBWAY','RAJASTHANI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','MUGHLAI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','BHOAMANURI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','BISRINIVAS CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SUBWAY','KASHMIRI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','SOUTH INDIAN CUISINES','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','KERALA CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SUBWAY','TAMIL CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','ANDHRA CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','CUISINE OF KARNATAKA','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SUBWAY','TELANGANA CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','HYDERABADI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','EAST INDIAN CUISINES','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SUBWAY','ORIYA CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','NORTH EAST INDIAN CUISINES','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','SIKKIMESE CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','ASSAMESE CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SUBWAY','TRADITIONAL NORTH INDIAN THALI','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','NORTH INDIAN THALI','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','TRIPURI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SUBWAY','NAGA CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','WEST INDIAN CUISINES','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','GOAN CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SUBWAY','GUJARATI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','MAHARASHTRIAN CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','MALVANI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','PARSI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','RAJASTHANI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','INDIAN CHINESE CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SUBWAY','JAIN (SATVIKA) CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','SOUTH INDIAN VEGETARIAN THALI','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','SINDHI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','CHETTINAD CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SUBWAY','UDUPI CUISINE','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','INDIAN FAST FOOD','EXPENSIVE','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','INDIAN','CHEAP','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','PARADISE','INDIAN','MEDIUM','EAST',5)");
conn.execute("INSERT INTO RESTAURANTRESERVATION(RESERVEDONTHENAME,RESTAURANTNAME,CUISINETYPE,COSTTYPE,LOCATION,NOOFPEOPLE) VALUES ('RAVI','SUBWAY','INDIAN','EXPENSIVE','EAST',5)");

conn.commit()
print("Restaurant Records inserted successfully");
conn.close()
# Out:
# Restaurant Records inserted successfully
